# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/LocalPayNYC.csv")

# %%
df.head()
# Out:
#    data_year                             agency_name            job_category  \
# 0       2018  ADMINISTRATION FOR CHILDREN'S SERVICES  ADMINISTRATIVE SUPPORT
# 1       2018  ADMINISTRATION FOR CHILDREN'S SERVICES  ADMINISTRATIVE SUPPORT
# 2       2018  ADMINISTRATION FOR CHILDREN'S SERVICES  ADMINISTRATIVE SUPPORT
# 3       2018  ADMINISTRATION FOR CHILDREN'S SERVICES  ADMINISTRATIVE SUPPORT
# 4       2018  ADMINISTRATION FOR CHILDREN'S SERVICES  ADMINISTRATIVE SUPPORT
#
#       pay_band  lower_pay_band_bound  upper_pay_band_bound employee_status  \
# 0  30000-34999               30000.0               34999.0       Full-Time
# 1  30000-34999               30000.0               34999.0       Full-Time
# 2  30000-34999               30000.0               34999.0       Full-Time
# 3  30000-34999               30000.0               34999.0       Full-Time
# 4  30000-34999               30000.0               34999.0       Full-Time
#
# ...

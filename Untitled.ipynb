# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import plotly.express as px

df = pd.read_csv('data/b_data.csv')
df.head()
# Out:
#   first_name     last_name       gender employment_sector personality_trait_1  \
# 0   Thatcher      Lindgren         Male            Retail         Neuroticism
# 1    Othilia  Stollenwerck      Agender        Government            Openness
# 2        Wye          Tydd         Male        Technology            Openness
# 3    Zebulon   Van Leeuwen         Male        Government         Neuroticism
# 4      Timmi       Gazzard  Genderqueer            Retail        Extraversion
#
#          salary                 state
# 0         <$50k               Arizona
# 1        >$500k  District of Columbia
# 2        >$500k            California
# 3         <$50k              Maryland
# 4  $250 - $500k              New York

# %%
fig = px.line(df, y='salary', x="employment_sector")
fig.show()
# Out:
# <div>                            <div id="4dbb7e46-4f6b-4436-bc13-99717f96c606" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4dbb7e46-4f6b-4436-bc13-99717f96c606")) {                    Plotly.newPlot(                        "4dbb7e46-4f6b-4436-bc13-99717f96c606",                        [{"hovertemplate":"employment_sector=%{x}\u003cbr\u003esalary=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["Retail","Government","Technology","Government","Retail","Government","Retail","Hospitality","Entertainment","Education","Entertainment","Government","Retail","Retail","Government","Retail","Government","R
# ...

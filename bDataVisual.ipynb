# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  # Corrected import statement
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

df = pd.read_csv('data/b_data.csv')

df.head(10)
# Out:
#   first_name   last_name       sector  agreeableness  conscientiousness  \
# 0      Quint      Balcon   government              3                  3
# 1     Ianthe  Larkworthy    marketing              2                  1
# 2        Lyn     Maymond  hospitality              2                  3
# 3    Brittni     Brandli    marketing              1                  1
# 4     Bambie    MacCourt    marketing              2                  1
# 5    Brianna     Morican  agriculture              3                  2
# 6      Tresa   Slaymaker  hospitality              2                  2
# 7    Phineas     Gisburn      finance              3                  2
# 8    Lorilee    Castagne    marketing              3                  1
# 9      Windy     Grahame   government              3                  2
#
#    extroversion  neuroticism  openness   salary
# 0             2            3         3   51-100
# 1             2            1         2  101-150
# ...

# %%
size_data = df.groupby(['agreeableness', 'salary', 'sector']).size().reset_index(name='count')

# Scatter plot with size
plt.figure(figsize=(12, 8))
sns.scatterplot(x='agreeableness', y='salary', hue='sector', size='count', sizes=(20, 200), data=size_data, palette='viridis')

# Customize plot
plt.title('Scatter Plot of Agreeableness vs Salary Range (Size Reflects Count)')
plt.xlabel('Agreeableness')
plt.ylabel('Salary Range')
plt.legend(title='Sector')

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
print(size_data['sector'].dtype)
# Out:
# object

# %%
print(size_data['sector'].isnull().sum())
# Out:
# 0

# %%
size_data = df.groupby(['agreeableness', 'salary', 'sector']).size().reset_index(name='count')

# Bar chart
plt.figure(figsize=(12, 8))
sns.barplot(x='agreeableness', y='count', hue='sector', data=size_data, palette='viridis')

# Customize plot
plt.title('Bar Chart of Agreeableness vs Count (Grouped by Salary and Sector)')
plt.xlabel('Agreeableness')
plt.ylabel('Count')
plt.legend(title='Sector', loc='upper right')

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
# Include 'sector' in the grouping
size_data = df.groupby(['agreeableness', 'salary', 'sector']).size().reset_index(name='count')

# Bar chart
plt.figure(figsize=(12, 8))
sns.barplot(x='agreeableness', y='salary', hue='sector', data=size_data, palette='viridis')

# Customize plot
plt.title('Bar Chart of Agreeableness vs Count (Grouped by Salary and Sector)')
plt.xlabel('Agreeableness')
plt.ylabel('Count')
plt.legend(title='Sector', loc='upper right')

# Show the plot
plt.show()
# Out:
# /usr/local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /usr/local/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

df = pd.read_csv('b_data.csv')
df.head()
# Out:
#   first_name   last_name       sector  agreeableness  conscientiousness  \
# 0      Quint      Balcon   government              3                  3
# 1     Ianthe  Larkworthy    marketing              2                  1
# 2        Lyn     Maymond  hospitality              2                  3
# 3    Brittni     Brandli    marketing              1                  1
# 4     Bambie    MacCourt    marketing              2                  1
#
#    extroversion  neuroticism  openness   salary
# 0             2            3         3   51-100
# 1             2            1         2  101-150
# 2             3            3         2  101-150
# 3             2            1         1  151-250
# 4             3            2         2  251-500

# %%
columns_to_drop = ['first_name', 'last_name']
df = df.drop(columns=columns_to_drop)

# %%
df.head()
# Out:
#         sector  agreeableness  conscientiousness  extroversion  neuroticism  \
# 0   government              3                  3             2            3
# 1    marketing              2                  1             2            1
# 2  hospitality              2                  3             3            3
# 3    marketing              1                  1             2            1
# 4    marketing              2                  1             3            2
#
#    openness   salary
# 0         3   51-100
# 1         2  101-150
# 2         2  101-150
# 3         1  151-250
# 4         2  251-500

# %%
output_file_path = 'b_dataMod.csv'
df.to_csv(output_file_path, index=False)

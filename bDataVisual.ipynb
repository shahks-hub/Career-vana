# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt  # Corrected import statement
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

df = pd.read_csv('data/b_data.csv')

df.head(10)
# Out:
#   first_name     last_name         sector   salary  agreeableness  \
# 0      Kelsi     Pottberry    hospitality  101-150              2
# 1     Cassey       Rowbrey    hospitality  101-150              3
# 2        Jed       Mullett    hospitality  101-150              2
# 3   Fidelity  Shuttleworth        finance  101-150              3
# 4     Rhodie       Fencott    hospitality   51-100              3
# 5     Anissa       Niessen     healthcare  101-150              3
# 6  Gottfried         Meeks  entertainment       50              2
# 7        Ker      Ghidotti      marketing       50              1
# 8      Meyer        Fenlon      marketing       50              1
# 9    Waverly        Gommes  entertainment  151-250              3
#
#    conscientiousness  extroversion  neuroticism  openness
# 0                  2             3            2         2
# 1                  1             3            1         1
# 2                  3             2            2         3
# ...

# %%
# Scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='agreeableness', y='salary_range', hue='sector', data=df, palette='viridis')

# Customize plot
plt.title('Scatter Plot of Agreeableness vs Salary Range')
plt.xlabel('Agreeableness')
plt.ylabel('Salary Range')
plt.legend(title='Sector')

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 # Scatter plot
#       2 plt.figure(figsize=(10, 6))
# ----> 3 sns.scatterplot(x='agreeableness', y='salary_range', hue='sector', data=df, palette='viridis')
#       5 # Customize plot
#       6 plt.title('Scatter Plot of Agreeableness vs Salary Range')
#
# File /usr/local/lib/python3.11/site-packages/seaborn/relational.py:742, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     732 def scatterplot(
#     733     data=None, *,
#     734     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     738     **kwargs
#     739 ):
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
# ...

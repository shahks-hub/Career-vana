# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import plotly.express as px

df = pd.read_csv('data/mock_data.csv')
df.head()
# Out:
#   first_name   last_name gender employment_sector  personality_trait  salary  \
# 0     Cornie     Sharram   Male           finance  conscientiousness  255516
# 1      Merry      Stolte   Male        technology  conscientiousness  242745
# 2      Normy    Petrozzi   Male         education       extraversion  283361
# 3       Brit   McMarquis   Male       hospitality  conscientiousness  263186
# 4       Carl  MacClancey   Male        healthcare  conscientiousness  437109
#
#         state
# 0    Virginia
# 1    Virginia
# 2    Colorado
# 3  California
# 4     Arizona

# %%
fig = px.box(df, y='salary', x="employment_sector")
fig.show()
